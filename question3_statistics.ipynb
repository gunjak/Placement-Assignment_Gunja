# %% [markdown]
# <a href="https://colab.research.google.com/github/gunjak/Placement-Assignment_Gunja/blob/main/question3_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/detection_number_plate/data (1).csv')
df.std()
# Out:
# Patient ID                       29.011492
#  Blood Pressure Before (mmHg)     6.598278
#  Blood Pressure After (mmHg)      6.888022
# dtype: float64

# %%
import numpy as np
import scipy.stats as st
df.iloc[:,0].mean(),df.iloc[:,1].mean()
# Out:
# (50.5, 133.91)

# %%
st.norm.interval(confidence=0.05,
              loc=df.iloc[:,0].mean(),
              scale=st.sem(df.iloc[:,0]))
# Out:
# (50.318078281486706, 50.681921718513294)

# %%
st.norm.interval(confidence=0.05,
              loc=df.iloc[:,1].mean(),
              scale=st.sem(df.iloc[:,1]))
# Out:
# (133.86862432458767, 133.95137567541232)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
  
# generate random data
np.random.seed(0)
x = df.iloc[:,0]
y = df.iloc[:,1]
  
# create lineplot
ax = sns.regplot(x=x,y=y,ci=5)

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/detection_number_plate/data (1).csv')

# %%
df.columns
# Out:
# Index(['Patient ID', ' Blood Pressure Before (mmHg)',
#        ' Blood Pressure After (mmHg)'],
#       dtype='object')

# %%
s=df[' Blood Pressure Before (mmHg)']- df[' Blood Pressure After (mmHg)']

# %%
import seaborn as sns
sns.distplot(s)
# Out:
# <ipython-input-7-bd49147c9f77>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(s)
# <Axes: ylabel='Density'>
